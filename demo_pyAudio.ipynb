# %%
from speakerDiarization import speakerDiarization as sD

# %%
# create the instance of the class

sd = sD.speakerDiarization(audio_filepath='./data/test1.wav',
                           vad_filepath='./data/test1_vad.json',
                           num_speakers=2)

# %%
# calculate the new vad output file

new_vad = sd.speaker_diarization('./data/new_vad.json')
# Out:
# /Users/hbin/Desktop/speaker/venv/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:466: ChangedBehaviorWarning: n_components cannot be larger than min(n_features, n_classes - 1). Using min(n_features, n_classes - 1) = min(26, 135 - 1) = 26 components.
#   ChangedBehaviorWarning)
# /Users/hbin/Desktop/speaker/venv/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:472: FutureWarning: In version 0.23, setting n_components > min(n_features, n_classes - 1) will raise a ValueError. You should set n_components to None (default), or a value smaller or equal to min(n_features, n_classes - 1).
#   warnings.warn(future_msg, FutureWarning)

# %%
# plot the predicted speakers along the time

sd.plot_diarization()

# %%
# Accuracy comparing to the ground truth file

sd.evaluate_diarization_accuracy('./data/test1_gt.json')
# Out:
# 0.9387436887436916

# %%
# Average cluster and speaker purity

sd.evaluate_diarization_purity('./data/test1_gt.json')
# Out:
# Speaker purity: 94.4% - Cluster purity: 94.4%
# (0.9436786720023714, 0.9436786720023714)

# %%
# plot the both predicted and ground truth speakers along the time

sd.plot_diarization()
